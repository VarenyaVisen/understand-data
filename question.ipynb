# %% [markdown]
# ## Understanding Data
# Questions to ask after getting your data

# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\varen\OneDrive\Documents\Machine Learning\data_questions\data\train.csv')

# %% [markdown]
# ## 1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # 2. How does the data look like?

# %%
# Sometimes data is biased so instead of using head we use sample to take random rows from the data
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 836          837         0       3                           Pasic, Mr. Jakob
# 521          522         0       3                            Vovk, Mr. Janko
# 272          273         1       2  Mellinger, Mrs. (Elizabeth Anne Maidment)
# 816          817         0       3               Heininen, Miss. Wendla Maria
# 336          337         0       1                  Pears, Mr. Thomas Clinton
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 836    male  21.0      0      0            315097   8.6625   NaN        S
# 521    male  22.0      0      0            349252   7.8958   NaN        S
# 272  female  41.0      0      1            250644  19.5000   NaN        S
# 816  female  23.0      0      0  STON/O2. 3101290   7.9250   NaN        S
# 336    male  29.0      1      0            113776  66.6000    C2        S

# %% [markdown]
# # 3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # 6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 7. How is the correlation between cols?

# %%
df_numeric = df.select_dtypes(include=['number'])
correlations = df_numeric.corr()['Survived']
print(correlations)
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
